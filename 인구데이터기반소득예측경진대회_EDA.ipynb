# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#개요" data-toc-modified-id="개요-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>개요</a></span><ul class="toc-item"><li><span><a href="#예" data-toc-modified-id="예-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>예</a></span></li><li><span><a href="#데이터" data-toc-modified-id="데이터-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>데이터</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#기본-EDA" data-toc-modified-id="기본-EDA-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>기본 EDA</a></span></li><li><span><a href="#기본-EDA-결과" data-toc-modified-id="기본-EDA-결과-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>기본 EDA 결과</a></span></li></ul></li><li><span><a href="#변수분석" data-toc-modified-id="변수분석-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>변수분석</a></span><ul class="toc-item"><li><span><a href="#연속형변수" data-toc-modified-id="연속형변수-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>연속형변수</a></span><ul class="toc-item"><li><span><a href="#age" data-toc-modified-id="age-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>age</a></span></li><li><span><a href="#fnlwgt" data-toc-modified-id="fnlwgt-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>fnlwgt</a></span></li><li><span><a href="#capital.gain" data-toc-modified-id="capital.gain-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>capital.gain</a></span></li><li><span><a href="#capital.loss" data-toc-modified-id="capital.loss-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>capital.loss</a></span></li><li><span><a href="#hours.per.week" data-toc-modified-id="hours.per.week-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>hours.per.week</a></span></li></ul></li><li><span><a href="#서열형-변수" data-toc-modified-id="서열형-변수-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>서열형 변수</a></span><ul class="toc-item"><li><span><a href="#education.num" data-toc-modified-id="education.num-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>education.num</a></span></li></ul></li><li><span><a href="#명목형-변수" data-toc-modified-id="명목형-변수-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>명목형 변수</a></span><ul class="toc-item"><li><span><a href="#edcation" data-toc-modified-id="edcation-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>edcation</a></span></li><li><span><a href="#marital.status" data-toc-modified-id="marital.status-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>marital.status</a></span></li><li><span><a href="#relationship" data-toc-modified-id="relationship-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>relationship</a></span></li><li><span><a href="#race" data-toc-modified-id="race-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>race</a></span></li><li><span><a href="#sex" data-toc-modified-id="sex-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>sex</a></span></li><li><span><a href="#workclass" data-toc-modified-id="workclass-3.3.6"><span class="toc-item-num">3.3.6&nbsp;&nbsp;</span>workclass</a></span></li><li><span><a href="#occupation" data-toc-modified-id="occupation-3.3.7"><span class="toc-item-num">3.3.7&nbsp;&nbsp;</span>occupation</a></span></li><li><span><a href="#native.country" data-toc-modified-id="native.country-3.3.8"><span class="toc-item-num">3.3.8&nbsp;&nbsp;</span>native.country</a></span></li></ul></li></ul></li><li><span><a href="#변수-분석-결과" data-toc-modified-id="변수-분석-결과-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>변수 분석 결과</a></span></li></ul></div>

# %% [markdown]
# # 개요
# 데이콘 베이직 Basic | 정형 | Accuracy
# - 상금 : 참가시 최소 50 XP, 특별상 데이콘 후드
# - 2022.04.18 ~ 2022.04.29 18:0
# https://dacon.io/competitions/official/235892/data
#
# ## 예
#
# ## 데이터
# 1. train.csv : 학습 데이터
#
# - id : 샘플 아이디
# - age : 나이
# - workclass : 일 유형
# - fnlwgt : CPS(Current Population Survey) 가중치
# - education : 교육수준
# - education.num : 교육수준 번호
# - marital.status : 결혼 상태
# - occupation : 직업
# - relationship : 가족관계
# - race : 인종
# - sex : 성별
# - capital.gain : 자본 이익
# - capital.loss : 자본 손실
# - hours.per.week : 주당 근무시간
# - native.country : 본 국적
# - target : 소득
#  - 0 = <=50K (5만 달러 이하)
#  - 1 = >50K (5만 달러 초과)
#
#
#
# 2. test.csv : 테스트 데이터
#
# - id : 샘플 아이디
# - age : 나이
# - workclass : 일 유형
# - fnlwgt : CPS(Current Population Survey) 가중치
# - education : 교육수준
# - education.num : 교육수준 번호
# - marital.status : 결혼 상태
# - occupation : 직업
# - relationship : 가족관계
# - race : 인종
# - sex : 성별
# - capital.gain : 자본 이익
# - capital.loss : 자본 손실
# - hours.per.week : 주당 근무시간
# - native.country : 본 국적
#
#
#
# 3. sample_submission.csv : 제출 양식
#
# - id : 샘플 아이디
# - target : 소득

# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('./train.csv')
test=pd.read_csv('./test.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## 기본 EDA

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17480 entries, 0 to 17479
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              17480 non-null  int64
#  1   age             17480 non-null  int64
#  2   workclass       15644 non-null  object
#  3   fnlwgt          17480 non-null  int64
#  4   education       17480 non-null  object
#  5   education.num   17480 non-null  int64
#  6   marital.status  17480 non-null  object
#  7   occupation      15637 non-null  object
#  8   relationship    17480 non-null  object
#  9   race            17480 non-null  object
#  10  sex             17480 non-null  object
#  11  capital.gain    17480 non-null  int64
#  12  capital.loss    17480 non-null  int64
#  13  hours.per.week  17480 non-null  int64
#  14  native.country  16897 non-null  object
#  15  target          17480 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 2.1+ MB

# %%
train.describe(include='all')
# Out:
#                   id           age workclass        fnlwgt education  \
# count   17480.000000  17480.000000     15644  1.748000e+04     17480
# unique           NaN           NaN         8           NaN        16
# top              NaN           NaN   Private           NaN   HS-grad
# freq             NaN           NaN     11568           NaN      5566
# mean     8739.500000     38.720995       NaN  1.897610e+05       NaN
# std      5046.185688     14.079617       NaN  1.049929e+05       NaN
# min         0.000000     17.000000       NaN  1.228500e+04       NaN
# 25%      4369.750000     27.000000       NaN  1.181558e+05       NaN
# 50%      8739.500000     37.000000       NaN  1.781340e+05       NaN
# 75%     13109.250000     48.000000       NaN  2.373180e+05       NaN
# max     17479.000000     90.000000       NaN  1.455435e+06       NaN
#
#         education.num      marital.status       occupation relationship  \
# ...

# %%
cate_feat = []
num_feat = []
for col in train.columns:
    target = train[col]
    if target.nunique() <=20:
        cate_feat.append(col)
    else:
        num_feat.append(col)
print('범주형 :', cate_feat)
print('연속형: ', num_feat)
# Out:
# 범주형 : ['workclass', 'education', 'education.num', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'target']
# 연속형:  ['id', 'age', 'fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week', 'native.country']

# %%
# 범주형 상관관계
from scipy.stats import chi2_contingency, chisquare

corr_list= []

for i in cate_feat:
    c_list = []
    for j in cate_feat:
        ct = pd.crosstab(train[i],train[j])
        result=chi2_contingency(observed=ct)
        c = np.sqrt(result[0]/(len(train)*(min(len(train[i].unique()),len(train[j].unique()))-1)))
        c_list.append(c)
    corr_list.append(c_list)
corr_df = pd.DataFrame(corr_list,columns=cate_feat, index=cate_feat)

sns.set(rc = {'figure.figsize':(20,12)})
sns.heatmap(corr_df,vmin=-1,vmax=1,cmap='RdBu',linewidths=.1,annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
#숫자형 상관관계
numeric_feat = []
for col in train.columns:
    if train[col].dtype == 'int64' or 'float64':
        numeric_feat.append(col)
        
num_corr = train[numeric_feat].corr(method='pearson') #spearman

sns.set(rc = {'figure.figsize':(20,12)})
sns.heatmap(num_corr,vmin=-1,vmax=1,cmap='RdBu',linewidths=.1,annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt 
train.plot(kind='box',subplots=True,layout = (7,4),figsize=(20,30))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 기본 EDA 결과

# %% [markdown]
# 1. workclass, occupation 에 결측치 존재
#
# - 직업이 없으면 결측치 인가? -> 생각해 볼 점
#
# - test 데이터에는 workclass의 Never-worked가 없음
#
#
# 3. education.num과 education은 같은 변수 -> 하나를 제거
#
# 4. relationship, sex가 상관관계가 있음(0.6 이상)
#
# 6. 이상치
#
# - 이상치가 매우 많은데 자본이익이나 자본손실의 경우 0이 많기 떄문에 많을 수 밖에 없고, 주당 근무시간과 fnlwgt의 변수 특성상 이상치가 많을 수 밖에 없음. 또한 대부분 극단적인 이상치가 아니기 때문에 어떻게 처리해야할지 고민, 대부분의 팀은 안한 것으로 보임

# %% [markdown]
# # 변수분석

# %% [markdown]
# ## 연속형변수

# %% [markdown]
# 연속형 변수는 정규분포를 따르지 않는 것이 많아서 로그변환한 것도 시각화 하여 살펴봤습니다

# %% [markdown]
# ### age

# %%
f, axes = plt.subplots(2, figsize=(8, 6))

sns.histplot(x=train['age'],bins=10,hue=train['target'], ax=axes[0])
sns.histplot(x=np.log1p(train['age']),bins=10,hue=(train['target']), ax=axes[1])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# - 나이대에 따라 타겟의 비율이 다른 것을 확인 -> 나이대로 범주형 변수 생성

# %% [markdown]
# ### fnlwgt

# %%
f, axes = plt.subplots(2, figsize=(8, 6))

sns.histplot(x=train['fnlwgt'],bins=100,hue=train['target'], ax=axes[0])
sns.histplot(x=np.log1p(train['fnlwgt']),bins=100,hue=train['target'], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Count'>

# %% [markdown]
# - 점수별로 큰 차이가 있는 것 같지는 않음

# %% [markdown]
# ### capital.gain

# %%
f, axes = plt.subplots(2, figsize=(8, 6))

sns.histplot(x=train['capital.gain'],bins=10,hue=train['target'], ax=axes[0])
sns.histplot(x=np.log1p(train['capital.gain']),bins=10,hue=train['target'], ax=axes[1])
# Out:
# <AxesSubplot:xlabel='capital.gain', ylabel='Count'>

# %% [markdown]
# - 0 값이 너무 많음 -> 로그변환 의미x
#
# - 자본이익이 많다고 해서 무조건 타겟이 1인 것도 아님

# %% [markdown]
# ### capital.loss

# %%
f, axes = plt.subplots(2, figsize=(8, 6))

sns.histplot(x=train['capital.loss'],bins=10,hue=train['target'], ax=axes[0])
sns.histplot(x=np.log1p(train['capital.loss']),bins=10,hue=np.log1p(train['target']), ax=axes[1])
# Out:
# <AxesSubplot:xlabel='capital.loss', ylabel='Count'>

# %% [markdown]
# - 자본이익과 마찬가지

# %% [markdown]
# ### hours.per.week

# %%
f, axes = plt.subplots(2, figsize=(8, 6))

sns.histplot(x=train['hours.per.week'],bins=10,hue=train['target'], ax=axes[0])
sns.histplot(x=np.log1p(train['hours.per.week']),bins=10,hue=np.log1p(train['target']), ax=axes[1])
# Out:
# <AxesSubplot:xlabel='hours.per.week', ylabel='Count'>

# %% [markdown]
# - 업무시간이 늘수록 타겟이 1인 비율이 확실하게 느는 것을 확인할 수 있음

# %% [markdown]
# ## 서열형 변수

# %% [markdown]
# ### education.num

# %%
sns.histplot(x=train['education.num'],bins=10,hue=train['target'])
# Out:
# <AxesSubplot:xlabel='education.num', ylabel='Count'>

# %% [markdown]
# - 교육수준이 높을 수록 타겟이 1일 확율이 훨씬 높음

# %% [markdown]
# ## 명목형 변수

# %% [markdown]
# ### edcation

# %%
i='education'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - 교육수준이 높을 수록 타겟 1의 비율이 높음

# %% [markdown]
# ### marital.status

# %%
i='marital.status'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - Married-civ-spouse가 다른 항목에 비해 1의 비율의 압도적으로 많음

# %% [markdown]
# ### relationship

# %%
i='relationship'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - Husband, Wife가 다른 항목에 비해 1의 비율이 압도적으로 높음

# %% [markdown]
# ### race

# %%
i='race'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - white가 상대적으로 타켓 1의 비율이 높음

# %% [markdown]
# ### sex

# %%
i='sex'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - 남성이 타겟 1의 비율이 높음

# %% [markdown]
# ### workclass

# %%
i='workclass'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - workclass에 따라 확실히 타겟의 비율이 크게 다름

# %% [markdown]
# ### occupation

# %%
i='occupation'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - 직업 종류에 따라 타겟의 분포가 다양함

# %% [markdown]
# ### native.country

# %%
i='native.country'

f, ax = plt.subplots(1,2,figsize=(12,6))

sns.countplot(x=i,hue='target',data=train, ax=ax[0])
plt.sca(ax[0])
plt.xticks(rotation=90)

sns.pointplot(x=i,y='target',data=train, ax=ax[1],join=False)
plt.sca(ax[1])
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# - 범주가 너무 많음

# %% [markdown]
# # 변수 분석 결과

# %% [markdown]
# - age는 범주형 변수로 변환
#
# - fnlwgt는 로그변환하고 나머지 연속형 변수는 그대로 사용하기로함
#
# - education.num, relationship, native.country 제거
#
# - 범주형 변수를 더 낮은 수준의 범주로 변환할지 고민
